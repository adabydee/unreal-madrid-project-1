# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
final_df = pd.read_csv('final.csv')
out_of_sample = pd.read_csv('Out_of_Sample.csv')
out_of_sample = out_of_sample.drop(['Visitor-Points', 'Home-Points'], 1)
final_df = final_df.drop(['Visitor-Points', 'Home-Points'], 1)

# %%
final_df.sample(10)
# Out:
#       Overtime  Age_Visitor  W_Visitor  L_Visitor  PW_Visitor  PL_Visitor  \
# 2279         0         23.3         10         72          16          66
# 3950         0         25.6         42         40          40          42
# 1509         0         26.0         29         53          31          51
# 2054         1         27.6         42         40          37          45
# 3853         0         25.3         29         53          24          58
# 1757         0         23.2         18         64          18          64
# 3359         0         26.0         49         33          46          36
# 1979         1         27.8         60         22          56          26
# 2185         0         26.5         17         65          17          65
# 3200         0         25.8         55         27          59          23
#
#       MOV_Visitor  SOS_Visitor  SRS_Visitor  ORtg_Visitor       ...        \
# 2279       -10.23         0.31        -9.92          98.8       ...
# 3950        -0.18        -0.26        -0.45         109.1       ...
# 1509        -3.71         0.64        -3.07         105.3       ...
# 2054        -1.48         0.01        -1.46         105.0       ...
# 3853        -6.57        -0.04        -6.61         103.7       ...
# 1757        -8.98        -0.07        -9.04          95.5       ...
# 3359         1.80        -0.45         1.36         111.2       ...
# 1979         5.43        -0.68         4.75         108.9       ...
# 2185        -9.56         0.64        -8.92         101.6       ...
# 3200         7.28        -0.19         7.09         113.1       ...
#
#       T_DRB_Home  T_TRB_Home  T_AST_Home  T_STL_Home  T_BLK_Home  T_TOV_Home  \
# 2279        30.5        41.6        20.7         8.8         4.3        13.3
# 3950        34.1        44.3        23.6         8.2         4.8        15.8
# 1509        31.4        42.1        23.6         9.6         4.9        16.7
# 2054        33.9        46.3        19.4         7.0         3.7        13.5
# 3853        33.0        42.0        22.5         8.2         5.0        13.8
# 1757        32.3        43.9        20.9         7.0         4.5        13.2
# 3359        34.1        44.3        23.6         8.2         4.8        15.8
# 1979        32.0        42.4        20.9         7.0         4.1        13.8
# 2185        33.3        44.8        20.7         7.7         3.8        17.2
# 3200        33.9        45.5        21.3         6.9         4.6        14.6
#
#       T_PF_Home  T_PTS_Home    elo_diff  score_gap_sign
# 2279       21.7        99.1  454.231090               8
# 3950       18.2       103.2   71.693557              13
# 1509       22.1        97.8  134.531611               8
# 2054       19.0       102.0  -89.663692               4
# 3853       19.5       105.1   77.365436              13
# 1757       21.2        98.5   16.102411              14
# 3359       18.2       103.2   70.748487              15
# 1979       19.3        98.0  -90.610267               5
# 2185       22.7       100.9  243.239542              19
# 3200       21.7       105.1  -55.533041               5
#
# [10 rows x 135 columns]

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
X = final_df.drop(['score_gap_sign'], axis = 1)
y = final_df['score_gap_sign']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 66)

# %%
lassoreg = linear_model.Lasso(alpha=1)
lassoreg.fit(X_train, y_train)
print(lassoreg.coef_)
print(lassoreg.intercept_)
pred = lassoreg.predict(X_test)
error = np.sqrt(mean_squared_error(y_test, pred))
print(error)
# Out:
# [-0.00000000e+00  0.00000000e+00  8.93559367e-03 -0.00000000e+00
#  -1.62739305e-01  1.43430284e-15 -0.00000000e+00  0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -0.00000000e+00  0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00  0.00000000e+00  1.96481101e-01 -3.52067887e-17
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -0.00000000e+00  2.17467908e-03
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00  0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00  0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -0.00000000e+00  0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00  0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00  1.25901200e-02 -0.00000000e+00  0.00000000e+00
#  -0.00000000e+00  0.00000000e+00 -0.00000000e+00  0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00  0.00000000e+00  0.00000000e+00  5.99392537e-03
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  2.37992654e-02]
# -0.14745865977419514
# 11.675835166362408

# %%
# out-of-sample prediction
X_out = out_of_sample.drop(['score_gap_sign'], axis = 1)
y_out = out_of_sample['score_gap_sign']
lassoreg.fit(X,y)
pred = lassoreg.predict(X_out)
error = np.sqrt(mean_squared_error(y_out, pred))
print(pred)
print(error)
# Out:
# [ 1.96585181  5.13591976 -1.5537923   2.65708919  2.26987952  7.4281537
#  -1.09951493  0.64437457 -3.50360474 -0.93724605 -5.14610524  2.18543151
#   1.23799412  6.42537838  3.63866099 -0.20548532  1.18760754  0.02814541
#   0.11178111  0.18843944 -1.26193188  6.06969734 -3.18798825  0.45118402
#  -2.71807023 -2.72032173 -3.67873117  8.77671155  5.68816894 -5.39494182
#   0.70794927 -6.59658263  7.28158696  1.04405852 -3.67597855  5.77631018
#  -2.81122432 -2.64787324  3.87130101  7.75800768  0.92216158 12.54736597
#  -2.68127715  6.05317943 -0.84697988  2.94799886  4.6771249   7.12829457
#   5.68878601 -2.05651625  2.4226995   1.1730963  -2.32536268  4.70583811
#   7.48273859  1.83070503  4.24375627  0.51501633 -4.32078495  2.41221101
#   0.14355453  3.7630936  -1.30642031 -2.85511524 -1.8090175  -5.74828548
#   3.79154058  3.15066001 -1.47040091  6.20376091 -9.75023388 -0.45431122
#   8.09871448  0.59881965 -0.45442439 -3.21432883  2.85864674 -1.13320954
#   7.00453788  0.32537283  3.62898278  3.39044479 -8.46129541 -6.78982151
#   3.26120219  7.71574568 -9.52052811  0.51894783  0.7855425   1.79260078
#  -0.28784884  1.96853568 -0.31274878  6.23402604  6.59475491  4.49745631
#   0.49538923  5.61502676  2.18818996 -1.51530778  0.35828754 -2.74269079
#   2.0799597  -1.43417078 -6.09157252  4.3672507   3.82269276 -1.98972619
#  -5.50434812 -7.85898269]
# 12.754547309366664

# %%
# Visulization of prediction 
pred_list = list(pred)
y_out_list = list(y_out)
fig, ax = plt.subplots()
plt.xlabel('games')
plt.ylabel('actual score gap; predicted score gap')
yticks = range(-40,40,5)
ax.set_yticks(yticks)
ax.set_ylim([-40,40])
x = list(range(len(out_of_sample)))
plt.plot(x,pred_list,"x-",label="predicted score gap")
plt.plot(x,y_out_list,"+-",label="actual score gap")
plt.grid(True)
plt.legend(bbox_to_anchor=(1.0, 1), loc=1, borderaxespad=0.)

# %%
# Visulization of prediction 
import matplotlib.pyplot as plt
pred_list = list(pred)
y_out_list = list(y_out)
pred_actual_diff = [pred[i] - y_out[i] for i in range(len(pred))]
pred_actual_diff = [float(x) for x in pred_actual_diff]
fig, ax = plt.subplots()
plt.xlabel('games')
plt.ylabel('prediction error')
yticks = range(-40,40,5)
ax.set_yticks(yticks)
ax.set_ylim([-40,40])
x = list(range(len(out_of_sample)))
plt.plot(x, pred_actual_diff, label="difference between predicted and actual score")
plt.grid(True)
plt.legend(bbox_to_anchor=(1.0, 1), loc=1, borderaxespad=0.)
